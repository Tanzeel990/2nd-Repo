# %%
x = 5
if x ==5:
   print("x is 5")
elif x < 5:
   print("x is less then 5")
else:
     print("x is greater then 5")   
print("done!")
# Out:
# x is 5
# done!

# %%
x = -2
if x ==5:
   print("x is 5")
elif x < 5:
   print("x is less then 5")
else:
     print("x is greater then 5")   
print("Done!")
# Out:
# x is less then 5
# Done!

# %%
x = 10
if x ==5:
   print("x is 5")
elif x < 5:
   print("x is less then 5")
else:
     print("x is greater then 5")   
print("Done!")
# Out:
# x is greater then 5
# Done!

# %%
marks = 45
if marks>=90:
    print("A Grade")
elif marks>=80:
    print("B Grade")
elif marks>=50:
    print("C Grade")      
else:
    print("F Grade")
# Out:
# F Grade

# %%
marks = 55
if marks>=90:
    print("A Grade")
elif marks>=80:
    print("B Grade")
elif marks>=50:
    print("C Grade")      
else:
    print("F Grade")
# Out:
# C Grade

# %%
marks = 75
if marks>=90:
    print("A Grade")
elif marks>=80:
    print("B Grade")
elif marks>=50:
    print("C Grade")      
else:
    print("F Grade")
# Out:
# C Grade

# %%
marks = 85
if marks>=90:
    print("A Grade")
elif marks>=80:
    print("B Grade")
elif marks>=50:
    print("C Grade")      
else:
    print("F Grade")
# Out:
# B Grade

# %%
marks = 95
if marks>=90:
    print("A Grade")
elif marks>=80:
    print("B Grade")
elif marks>=50:
    print("C Grade")      
else:
    print("F Grade")
# Out:
# A Grade
